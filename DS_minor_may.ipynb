# %% [markdown]
# <a href="https://colab.research.google.com/github/snehapujari1234/DS-MINOR-MAY/blob/main/DS_minor_may.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***IMAGE CLASSIFICATION:-***
#
# ---

# %%
# !pip install ipython-autotime
# %load_ext autotime
# Out:
# ...
# time: 746 µs (started: 2021-06-19 00:33:34 +00:00)

# %% [markdown]
# # ***PROCEDURE:-***
#
# ---![4Procedure.jpg](data:image/jpeg;base64,...)

# %%
#Data :images
#1.Download manually the image from google
#2.Download dataset from kaggle.com 
#3.Build a image web crawler 
#4.using the python libraries to scrape the image(using)
# Out:
# time: 1.57 ms (started: 2021-06-19 00:54:54 +00:00)

# %% [markdown]
# # ***STEPS :-***
#
# ---
# ![78dfdef3-a0db-49ad-a59c-1da84323a388 (1).png](data:image/png;base64,...)

# %%
# !pip install bing-image-downloader
# Out:
# ...
# time: 3.03 s (started: 2021-06-19 01:05:14 +00:00)

# %% [markdown]
# #  Image Installation process:-
#
# ---

# %%
# !mkdir images
# Out:
# time: 119 ms (started: 2021-06-19 01:30:09 +00:00)

# %%
from bing_image_downloader import downloader
downloader.download("cars",limit=10,output_dir="images",adult_filter_off=True)
# Out:
# [%] Downloading Images to /content/images/cars
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 10 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://www.carbodydesign.com/archive/2009/08/05-sv-9-competizione-images/SV-9-Competizione-4-lg.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.pinimg.com/736x/73/62/d8/7362d822038afc4386906ce9ab2ce58c.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://shinecoco.com/wp-content/uploads/2020/04/gear_ghouly.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://media.whatcar.com/migration/article_inline/fa3f2b3925370291872ddcf823dd8719749dcae6.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://external-preview.redd.it/pbEfLIYe90hFmJFBXWG8K0oXU4ayUl-6-USZlF7G_qk.jpg?auto=webp&amp;s=b2d9b17a5a84826506058e26ddbaeead84d0761a
# ...

# %%
downloader.download("houses",limit=10,output_dir="images",adult_filter_off=True)
# Out:
# [%] Downloading Images to /content/images/houses
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 10 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://theoldhouselife.com/wp-content/uploads/2018/07/IS6a33ez181ikg0000000000.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.pinimg.com/originals/1b/95/1f/1b951f5003cfafb0732a1a7e186c012c.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://architecturerestoration.com/wp-content/uploads/2017/12/queenanne.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://technicalmethods.co.uk/wp-content/uploads/2018/08/slide-03.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://i.pinimg.com/originals/c1/5e/d9/c15ed9ab5b8dbdbe3ca66dff29a48f5c.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://i.pinimg.com/originals/12/57/65/1257658e0794f4fad4ba70935590ded9.jpg
# [%] File Downloaded !
#
# ...

# %%
downloader.download("beaches",limit=10,output_dir="images",adult_filter_off=True)
# Out:
# [%] Downloading Images to /content/images/beaches
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 10 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://www.tongaholiday.com/wp-content/uploads/2014/04/slider-beaches6.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://cdn.sandals.com/beaches/v12/images/resorts/btc/home/slideshow/aerial-beach-family.jpg
# [Error]Invalid image, not saving https://cdn.sandals.com/beaches/v12/images/resorts/btc/home/slideshow/aerial-beach-family.jpg
#
# [!] Issue getting: https://cdn.sandals.com/beaches/v12/images/resorts/btc/home/slideshow/aerial-beach-family.jpg
# [!] Error:: Invalid image, not saving https://cdn.sandals.com/beaches/v12/images/resorts/btc/home/slideshow/aerial-beach-family.jpg
#
# [%] Downloading Image #2 from https://mk0travelawayrru2xew.kinstacdn.com/wp-content/uploads/2013/06/phra-nang-beach-thailand.jpg
# [%] File Downloaded !
#
# ...

# %%
import numpy as np
a=np.array([[1,2,3,4,5],
           [3,4,5,6,7]])
a.ndim
# Out:
# 2

# %%
a.flatten()
# Out:
# array([1, 2, 3, 4, 5, 3, 4, 5, 6, 7])

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from skimage.io import imread 
from skimage.transform import resize

target=[]
images=[]
flat_data=[]

DATADIR='/content/images'
CATEGORIES=['cars','house','beaches']
for category in CATEGORIES:
  class_num = CATEGORIES.index(category)
  path=os.path.join(DATADIR,category)
  print(path)
# Out:
# /content/images/cars
# /content/images/house
# /content/images/beaches
